# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array_1 = np.random.rand(100)
array_2 = np.random.rand(100)

# %%
plt.plot(array_1)
plt.plot(array_2)
plt.show()

# %%
array_3 = array_2 - array_1

# %%
plt.plot(array_3)

# %%
array_3.mean()
# Out:
# -0.0075598691966060625
